# %%
# Find the val%e of T(2) for the rec%rrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.


T(n) = 3T(n-1) + 12n
T(1)=3T(1-1)+12*1
T(1)=3T(0)+12
T(1)=3*5+12
T(1)=15+12
T(1)=27


T(2)=3T(2-1)+12*2
T(2)=3T(1)+24
T(2)=3*27+24
T(2)=81+24
T(2)=105

# %%
# Given a rec%rrence relation, solve it %sing the s%bstit%tion method:
# a. T(n) = T(n-1) + c
# b. T(n) = 2T(n/2) + n
# c. T(n) = 2T(n/2) + c
# d. T(n) = T(n/2) + c


# a. T(n) = T(n-1) + c


T(n)=T(n-1)+c    --------------1
by substitute n by n-1
T(n-1)=T((n-1)-1)+c
T(n-1)=T(n-2)+c------------2
by substitute T(n-1) in eq 1
T(n)=T(n-2)+c+c
T(n)=T(n-2)+2c
if we substitue k times
T(n)=T(n-k)+Kc
T(n)=T(n-(n-1))+(n-1)c
T(n)=T(1)+nc-c
T(n)=1+nc+c
T(n)=O(n)



# b. T(n) = 2T(n/2) + n

T(n)=2T(n/2)+n    --------------1
by substitute n by n/2
T(n/2)=2T(n/2/2)+n/2
T(n/2)=2T(n/4)+n/2    ----------2
T(n/4)=2T(n/8)+n/4    ----------3
by substitute T(n/2) in eq 1
T(n)=2(2T(n/4)+(n/2))+n
T(n)=2^2 T(n/2^2)+2*n/2+n
T(n)=2^2 T(n/2^2)+n+n
T(n)=2^2 T(n/2^2)+2n    --------4
by substitute eq 3 in eq 4
T(n)=2^2 (2T(n/8)+(n/4))+2n
T(n)=2^3T(n/2^3)+n+2n
T(n)=2^3T(n/2^3)+3n
T(n)=2^4T(n/2^4)+4n
T(n)=2^kT(n/2^k)+kn
by substitute n/2^k=1 n=2^k logn=klog2 logn=k
T(n)=2^k T(1)+nlogn
T(n)=n*1+nlogn
T(n)=n+nlogn
T(n)=O(nlogn)


# c. T(n) = 2T(n/2) + c

T(n)=2T(n/2)+c    --------------1
by substitute n by n/2
T(n/2)=2T(n/2/2)+c
T(n/2)=2^2T(n/4)+c    ----------2
T(n/4)=2^3T(n/8)+c    ----------3
by substitute T(n/2) in eq 1
T(n)=2(2T(n/4)+c)+c
T(n)=2^2 T(n/2^2)+2*c+c
T(n)=2^2 T(n/2^2)+3c
T(n)=2^2 T(n/2^2)+3c    --------4
by substitute eq 3 in eq 4
T(n)=2^2 (2T(n/8)+c)+3c
T(n)=2^3T(n/2^3)+4c+3c
T(n)=2^3T(n/2^3)+7c
T(n)=2^4T(n/2^4)+c
T(n)=2^kT(n/2^k)+c
by substitute n/2^k=1 n=2^k logn=klog2 logn=k
T(n)=2^kT(1)+c
T(n)=n*T(1)+c
T(n)=n+c
T(n)=O(n)


# d. T(n) = T(n/2) + c

T(n)=T(n/2)+c
T(n/2)=T(n/4)+c
T(n)=T(n/4)+2c
T(n)=T(n/8)+3c
T(n)=T(n/2^k)+kc
by substitute n/2^k=1 n=2^k logn=klog2 logn=k
T(n)=T(1)+lognc
T(n)=O(logn)

# %%
# Given a rec%rrence relation, solve it %sing the rec%rsive tree approach:
# a. T(n) = 2T(n-1) +1
# b. T(n) = 2T(n/2) + n


# a. T(n) = 2T(n-1) +1
T(n)=2T(n-1)+1
T(n)=1+2^1+2^2+2^3....+2^k
this is gp series so a(r^k+1)-1/(r-1)
a=1,r=2
1(2^k+1)-1/(2-1)
T(n)=2^(k+1)-1
assume n-k=0,n=k
by put n=k 
T(n)=2^(n+1)-1
T(n)=O(2^n)


# b. T(n) = 2T(n/2) + n
T(n) = 2T(n/2) + n
steps required are n*k times
so time taken is nk
T(n)=nk
assume n/2^k=1,n=2^k,logn=klog2,logn=k
T(n)=n*logn
T(n)=O(nlogn)
